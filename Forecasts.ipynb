# %%
import Ratios as r

# %%
app = r.Ratios()
# Out:
# Which company do you want to analyze?: ['Apple_Inc', 'GOLDMAN_SACHS_GROUP_INC', 'Mastercard_Inc', 'Snowflake_Inc', 'Tesla,_Inc', 'ZYNEX_INC']
# Paste the compnay: apple_inc

# %%
app.ratios()
# Out:
#         Current Ratio Acid Ratio Cash Ratio Operating Cash Flow Ratio  \
# 06/2021      1.061891   1.013837   0.315998                   0.77805
# 03/2021      1.141749   1.092692   0.361574                  0.589782
# 12/2020      1.163003   1.125473   0.271759                  0.292535
# 06/2020       1.46945   1.427716   0.350228                    0.6305
# 03/2020      1.495962   1.461267    0.41807                  0.456085
# 12/2019      1.597782   1.557679   0.389297                  0.298705
# 06/2019      1.504649   1.467248   0.563297                  0.551603
# 03/2019      1.315382   1.263298    0.40511                  0.403585
# 12/2018      1.300555   1.254491   0.413463                  0.246484
# 06/2018     40.222724  38.160181  11.108756                  20.12196
# 03/2018     42.129252   39.64723  14.596372                 14.066408
# 12/2017      1.242011   1.203829   0.237425                  0.244352
# ...

# %%
plt.figure(figsize=(15, 10))
plt.plot(ratios["Earnings per share Ratio"])

# %%
plt.figure(figsize=(15, 10))
plt.plot(ratios["Current Ratio"])
